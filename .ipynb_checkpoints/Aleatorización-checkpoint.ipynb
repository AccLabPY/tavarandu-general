# %% [markdown]
# # Aleatorización Colegios
#
# ## Parámetros para los bloques: año y zona

# %%
# Importando las bibliotecas
import pandas as pd
import numpy as np

# Carga del dataset 
df = pd.read_csv('Colegios_Secciones.csv')

# Filtrar las filas donde la columna aleatorización tiene el valor "SI" 
df_filtered = df[(df["Incluido en la aleatorización"] == "SI")]
df_filtered_copy = df_filtered.copy()

# %%
def stratified_randomization(data, strata_cols, treatment_col, seed_value=10):
    # Establecer la semilla para reproducibilidad
    np.random.seed(seed_value)
    
    # Inicialización de la columna de tratamiento
    data[treatment_col] = None
    
    # Obtener valores únicos para cada estrato
    unique_strata = data[strata_cols].drop_duplicates()
    
    # Iterar sobre cada combinación única de estratos
    for _, stratum in unique_strata.iterrows():
        mask = (data[strata_cols] == stratum).all(axis=1)
        subset = data[mask]
        
        # Si solo hay una observación en el estrato, asignamos aleatoriamente
        if len(subset) == 1:
            assignments = ["control" if np.random.rand() < 0.5 else "treatment"]
        else:
            n_control = len(subset) // 2
            n_treatment = len(subset) - n_control
            assignments = ["control"] * n_control + ["treatment"] * n_treatment
            np.random.shuffle(assignments)
            
        data.loc[mask, treatment_col] = assignments
        
    return data

# Especificar las columnas de estrato, acá se puede agregar más estratos en el futuro con más casos
strata_columns = ['Zona', 'Año']

# Aplicar la aleatorización por bloques
df_randomized = stratified_randomization(df_filtered_copy, strata_columns, 'assignment')


df_randomized
# Out:
#                 Nombre de la institución   Sector    Zona        Tipo  \
# 0       COLEGIO NACIONAL DOMINGO ROBLEDO  Público  Urbana  Científico
# 1       COLEGIO NACIONAL DOMINGO ROBLEDO  Público  Urbana  Científico
# 2       COLEGIO NACIONAL DOMINGO ROBLEDO  Público  Urbana  Científico
# 3       COLEGIO NACIONAL DOMINGO ROBLEDO  Público  Urbana  Científico
# 6   COLEGIO NACIONAL PADRE RICARDO MUSCH  Público  Urbana     Técnico
# 7   COLEGIO NACIONAL PADRE RICARDO MUSCH  Público  Urbana     Técnico
# 8   COLEGIO NACIONAL PADRE RICARDO MUSCH  Público  Urbana     Técnico
# 9   COLEGIO NACIONAL PADRE RICARDO MUSCH  Público  Urbana     Técnico
# 12       COLEGIO NACIONAL PUERTO TRIUNFO  Público   Rural  Científico
# 13       COLEGIO NACIONAL PUERTO TRIUNFO  Público   Rural  Científico
# 15       COLEGIO NACIONAL NATALIO KM. 23  Público   Rural  Científico
# 16       COLEGIO NACIONAL NATALIO KM. 23  Público   Rural  Científico
#
#         Año       Sección         Turno  Número de varones matriculados  \
# 0   Primero             A         Tarde                             8.0
# 1   Primero             B         Tarde                            11.0
# 2   Segundo             A         Tarde                             7.0
# 3   Segundo             B        Mañana                            10.0
# 6   Primero   Informática  Mañana-Tarde                            13.0
# 7   Primero  Contabilidad  Mañana-Tarde                            11.0
# 8   Segundo   Informática        Mañana                            13.0
# 9   Segundo  Contabilidad  Mañana-Tarde                             6.0
# 12  Primero             A        Mañana                             8.0
# 13  Segundo             A        Mañana                            15.0
# 15  Primero             A        Mañana                            14.0
# 16  Segundo             A        Mañana                            15.0
#
#     Número de mujeres matriculadas  Promedio de edad  \
# 0                             12.0             15.70
# 1                             15.0             15.77
# 2                              8.0             16.53
# 3                             11.0             16.48
# 6                             15.0             15.11
# 7                             15.0             16.00
# 8                             11.0             16.21
# 9                             13.0             16.21
# 12                            15.0             15.43
# 13                            11.0             16.27
# 15                             6.0             15.90
# 16                            12.0             17.66
#
#    Incluido en la aleatorización assignment
# 0                             SI  treatment
# 1                             SI    control
# 2                             SI  treatment
# 3                             SI    control
# 6                             SI  treatment
# 7                             SI    control
# 8                             SI    control
# 9                             SI  treatment
# 12                            SI    control
# 13                            SI  treatment
# 15                            SI  treatment
# 16                            SI    control
